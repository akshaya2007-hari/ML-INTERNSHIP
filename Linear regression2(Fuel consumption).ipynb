# %%
 import pandas as pd
 import numpy as np
 from sklearn.linear_model import LinearRegression
 import matplotlib.pyplot as plt

# %%
 saldf=pd.read_csv('/content/drive/MyDrive/fuel_consumption.csv')

# %%
saldf.head()
# Out:
#            engineV    Type  2000  2001  2002  2003  2004  2005  2006  2007  \
# 0   901 to 1000 cc  Petrol  5.81  5.77  5.75  5.65  5.55  5.45  5.29  5.29
# 1  1001 to 1100 cc  Petrol  6.33  5.95  5.25  5.72  5.51  5.46  5.56  5.53
# 2  1101 to 1200 cc  Petrol  6.26  6.14  6.09  6.08  6.02  5.96  5.98  5.95
# 3  1201 to 1300 cc  Petrol  6.55  6.34  6.32  6.21  6.27  6.12  5.89  5.89
# 4  1301 to 1400 cc  Petrol  6.86  6.81  6.77  6.73  6.76  6.67  6.63  6.58
#
#    2008  2009  2010  2011
# 0  5.29  5.16  4.91  4.88
# 1  5.57  5.39  5.04  5.01
# 2  5.86  5.82  5.61  5.45
# 3  5.85  5.67  5.52  5.39
# 4  6.55  6.43  6.11  5.74

# %%
saldf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   engineV  44 non-null     object
#  1   Type     44 non-null     object
#  2   2000     44 non-null     float64
#  3   2001     44 non-null     float64
#  4   2002     44 non-null     float64
#  5   2003     44 non-null     float64
#  6   2004     44 non-null     float64
#  7   2005     44 non-null     float64
#  8   2006     44 non-null     float64
#  9   2007     44 non-null     float64
#  10  2008     44 non-null     float64
#  11  2009     44 non-null     float64
#  12  2010     44 non-null     float64
#  13  2011     44 non-null     float64
# dtypes: float64(12), object(2)
# memory usage: 4.9+ KB

# %%
saldf.isnull().sum()
# Out:
# engineV    0
# Type       0
# 2000       0
# 2001       0
# 2002       0
# 2003       0
# 2004       0
# 2005       0
# 2006       0
# 2007       0
# 2008       0
# 2009       0
# 2010       0
# 2011       0
# dtype: int64

# %%
 saldf.dropna(inplace=True, how='all')

# %%
 saldf.isnull().sum()
# Out:
# engineV    0
# Type       0
# 2000       0
# 2001       0
# 2002       0
# 2003       0
# 2004       0
# 2005       0
# 2006       0
# 2007       0
# 2008       0
# 2009       0
# 2010       0
# 2011       0
# dtype: int64

# %%
 inp=saldf[['2007']]
 out=saldf['2008']

# %%
 LR=LinearRegression()

# %%
 LR.fit(inp,out)
# Out:
# LinearRegression()

# %%
 LR.predict([[5]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([4.98526867])
